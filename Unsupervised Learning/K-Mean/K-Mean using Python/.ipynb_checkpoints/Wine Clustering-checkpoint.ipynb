# %%
import matplotlib.pyplot as plt
import pandas as pd
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import seaborn as sns

# %%
# pip install ucimlrepo

# %% [markdown]
# ## 1. Import Data
# Dataset ini berisi data kimiawi dari anggur yang diklasifikasikan dalam 13 fitur kimia seperti alkohol, kandungan asam dan flavonoid. Dataset ini memiliki 13 fitur dan 178 data.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
wine = fetch_ucirepo(id=109) 
  
# data (as pandas dataframes) 
X = wine.data.features 
y = wine.data.targets

# %%
X
# Out:
#      Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  Total_phenols  \
# 0      14.23       1.71  2.43               15.6        127           2.80
# 1      13.20       1.78  2.14               11.2        100           2.65
# 2      13.16       2.36  2.67               18.6        101           2.80
# 3      14.37       1.95  2.50               16.8        113           3.85
# 4      13.24       2.59  2.87               21.0        118           2.80
# ..       ...        ...   ...                ...        ...            ...
# 173    13.71       5.65  2.45               20.5         95           1.68
# 174    13.40       3.91  2.48               23.0        102           1.80
# 175    13.27       4.28  2.26               20.0        120           1.59
# 176    13.17       2.59  2.37               20.0        120           1.65
# 177    14.13       4.10  2.74               24.5         96           2.05
#
# ...

# %% [markdown]
# ## Standarisasi data

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled[0:15]
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, -1.16959318,  1.91390522,
#          0.80899739,  1.03481896, -0.65956311,  1.22488398,  0.25171685,
#          0.36217728,  1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, -2.49084714,  0.01814502,
#          0.56864766,  0.73362894, -0.82071924, -0.54472099, -0.29332133,
#          0.40605066,  1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, -0.2687382 ,  0.08835836,
#          0.80899739,  1.21553297, -0.49840699,  2.13596773,  0.26901965,
#          0.31830389,  0.78858745,  1.39514818],
#        [ 1.69154964, -0.34681064,  0.4879264 , -0.80925118,  0.93091845,
#          2.49144552,  1.46652465, -0.98187536,  1.03215473,  1.18606801,
#         -0.42754369,  1.18407144,  2.33457383],
#        [ 0.29570023,  0.22769377,  1.84040254,  0.45194578,  1.28198515,
#          0.80899739,  0.66335127,  0.22679555,  0.40140444, -0.31927553,
#          0.36217728,  0.44960118, -0.03787401],
# ...

# %% [markdown]
# ## 3. Reduksi Dimensi dengan PCA
#
# Fitur-fitur dalam dataset ini mungkin berkorelasi, dan PCA dapat digunakan untuk mereduksi dimensi dan meningkatkan kinerja algoritma clustering seperti K-Means.

# %%
# Reduksi dimensi menggunakan PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
X_pca[0:15]
# Out:
# array([[ 3.31675081,  1.44346263],
#        [ 2.20946492, -0.33339289],
#        [ 2.51674015,  1.0311513 ],
#        [ 3.75706561,  2.75637191],
#        [ 1.00890849,  0.86983082],
#        [ 3.05025392,  2.12240111],
#        [ 2.44908967,  1.17485013],
#        [ 2.05943687,  1.60896307],
#        [ 2.5108743 ,  0.91807096],
#        [ 2.75362819,  0.78943767],
#        [ 3.47973668,  1.30233324],
#        [ 1.7547529 ,  0.61197723],
#        [ 2.11346234,  0.67570634],
#        [ 3.45815682,  1.13062988],
#        [ 4.31278391,  2.09597558]])

# %% [markdown]
# ## 4. Clustering dengan K-Means

# %% [markdown]
# Kita akan menerapkan K-Means pada data yang telah direduksi dimensinya menggunakan PCA.

# %%
# Menentukan jumlah cluster dan melakukan clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_pca)

# Menambahkan label cluster ke data
wine['Cluster'] = kmeans.labels_

# %% [markdown]
# ## 5. Visualisasi Hasil Clustering

# %%
# Plot hasil PCA
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], alpha=0.5, c=kmeans.labels_, cmap='viridis')
plt.title('PCA - Wine Dataset')
plt.xlabel('Komponen Utama 1')
plt.ylabel('Komponen Utama 2')
plt.colorbar(label='Target Class')
plt.show()

# %% [markdown]
# ## 5. Pemilihan K terbaik
# Pemilihan k terbaik bisa menggunakan teknik silhouette. Teknik ini menggunakan SSE (Sum of Square) di setiap nilai k. SSE yang sudah tidak terlalu jauh, maka bisa katakan k itulah yang terbaik.
#
# Berdasarkan grafik di bawah ini, bisa kita katakan bahwa jumlah cluster paling optimal adalah 4. Hal ini karena nilai SSE yang sudah tidak terlalu jauh jika kita pake k=4,k=5,k=6 dst.

# %%
# Menentukan jumlah cluster k dan menghitung Silhouette Score
silhouette_scores = []

for k in range(2, 12):  # K-means untuk k = 2 hingga k = 11
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_pca)
    
    # Menghitung Silhouette Score hanya jika k >= 2
    score = silhouette_score(X_scaled, kmeans.labels_)
    silhouette_scores.append(score)

# %%
# Visualisasi hasil Silhouette Score vs Jumlah Cluster
plt.figure(figsize=(8, 6))
plt.plot(range(2, 12), silhouette_scores, marker='o', color='b')
plt.title('Silhouette Score vs. Number of Clusters')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.xticks(range(2, 12))
plt.grid(True)
plt.show()

# Menampilkan hasil Silhouette Score untuk setiap k
for k, score in zip(range(2, 12), silhouette_scores):
    print(f'k = {k}: Silhouette Score = {score:.4f}')
# Out:
# k = 2: Silhouette Score = 0.2683
# k = 3: Silhouette Score = 0.2829
# k = 4: Silhouette Score = 0.2069
# k = 5: Silhouette Score = 0.1668
# k = 6: Silhouette Score = 0.1376
# k = 7: Silhouette Score = 0.1213
# k = 8: Silhouette Score = 0.1099
# k = 9: Silhouette Score = 0.0828
# k = 10: Silhouette Score = 0.0706
# k = 11: Silhouette Score = 0.0411

# %% [markdown]
# ## Kesimpulan
# Silhouette Score yang lebih tinggi menunjukkan bahwa clustering dengan jumlah cluster tertentu lebih terpisah dengan baik. Sehingga banyaknya cluster yang terbaik adalah 3 cluster.

# %% [markdown]
# # Reference
# - https://archive.ics.uci.edu/dataset/109/wine
